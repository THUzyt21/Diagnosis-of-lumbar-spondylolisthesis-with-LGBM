# %%
import numpy as np
from pycaret.classification import *
X_train = np.load('X_train.npy')
X_test = np.load('X_test.npy')
y_train = np.load('y_train.npy')
y_test = np.load('y_test.npy')
load_config('config.pkl')
model = load_model('model.pkl')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Transformation Pipeline and Model Successfully Loaded

# %%
lgbmClassfier = model.steps[-1][1]
lgbmClassfier
# Out:
# LGBMClassifier(bagging_fraction=0.5, bagging_freq=0, feature_fraction=0.5,
#                learning_rate=0.2, min_child_samples=21, min_split_gain=0.9,
#                n_estimators=150, num_leaves=30, random_state=0,
#                reg_alpha=0.0001, reg_lambda=0.005)

# %%
predict_model(lgbmClassfier)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b37e9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b37e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b37e9_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b37e9_row0_col1" class="data row0 col1" >0.9660</td>
#       <td id="T_b37e9_row0_col2" class="data row0 col2" >0.9832</td>
# ...

# %%
plot_model(lgbmClassfier, 'confusion_matrix')

# %%
# 显示分类报告
plot_model(lgbmClassfier, plot='class_report')

# %%
plot_model(lgbmClassfier, plot='parameter')
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree         1.0
# importance_type        split
# learning_rate            0.2
# max_depth                 -1
# min_child_samples         21
# min_child_weight       0.001
# min_split_gain           0.9
# n_estimators             150
# n_jobs                    -1
# num_leaves                30
# objective               None
# random_state               0
# reg_alpha             0.0001
# reg_lambda             0.005
# silent                  warn
# subsample                1.0
# subsample_for_bin     200000
# subsample_freq             0
# feature_fraction         0.5
# bagging_freq               0
# bagging_fraction         0.5

# %%
plot_model(lgbmClassfier,'auc')

# %%
plot_model(lgbmClassfier,'pr')
